# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score
import numpy as np
import pandas as pd
import ipywidgets as widgets
import matplotlib.pyplot as plt
import sklearn.linear_model

from google.colab import drive,files
drive.mount('/content/drive')

hls_all_raw = pd.read_csv("/content/HSL_16022024061254237.csv")
hls_slice = pd.DataFrame(hls_all_raw, columns =["Country","Indicator","Type of indicator","Time","Value"])

yaxis = "Labour market insecurity"
#yaxis = "Feeling safe at night"
#yaxis = "Life Satisfaction"

hls_ls = hls_slice.loc[hls_all_raw["Indicator"] == yaxis]

hls_train = hls_ls.loc[hls_ls["Time"] == 2016]
hls_train = hls_train.loc[hls_ls["Type of indicator"] == 'Average']


weo_raw = pd.read_csv("/content/WEOOct2023all.xls", sep='\t', encoding='ISO-8859-1')
weo_selected_measurement = weo_raw.loc[weo_raw['WEO Subject Code'].str.contains("NGDP_RPCH", na=False)]
weo_selected_measurement_2018 = pd.DataFrame(weo_selected_measurement, columns=['Country', '2018'])

merged_train_data = pd.merge(hls_train, weo_selected_measurement_2018, on="Country")
merged_train_data = merged_train_data.rename(columns={"Value": yaxis, "2018": "Income Measurement"})
merged_train_data = pd.DataFrame(merged_train_data, columns=['Country', yaxis, 'Income Measurement'])
print(merged_train_data)

X= np.c_[merged_train_data["Income Measurement"]]
Y= np.c_[merged_train_data[yaxis]]
x = X.tolist()
y = Y.tolist()

model = sklearn.linear_model.LinearRegression()
model.fit(X,Y)

predicts = model.predict(X)
# plot data
out1 = widgets.Output()
with out1:
  plt.scatter(x, y)
  plt.xlabel('Income')
  plt.ylabel(yaxis)
  plt.title("Data Plot")
  plt.show()


# plot predictions
predict_x = [x for x in range(901)]
predict_x = [[x/100] for x in predict_x]
predict_y = model.predict(predict_x)

out2 = widgets.Output()
with out2:
  plt.scatter(predict_x, predict_y)
  plt.scatter(x, y)
  plt.xlabel('Income')
  plt.ylabel(yaxis)
  plt.title("Prediction Line")
  plt.show()

evs = explained_variance_score(Y, predicts)
print("Explained Variance Score: ", evs)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score
import numpy as np
import pandas as pd
import ipywidgets as widgets
import matplotlib.pyplot as plt
import sklearn.linear_model

from google.colab import drive,files
drive.mount('/content/drive')

hls_all_raw = pd.read_csv("/content/HSL_16022024061254237.csv")
hls_slice = pd.DataFrame(hls_all_raw, columns =["Country","Indicator","Type of indicator","Time","Value"])

#yaxis = "Labour market insecurity"
yaxis = "Feeling safe at night"
#yaxis = "Life Satisfaction"

hls_ls = hls_slice.loc[hls_all_raw["Indicator"] == yaxis]

hls_train = hls_ls.loc[hls_ls["Time"] == 2016]
hls_train = hls_train.loc[hls_ls["Type of indicator"] == 'Average']


weo_raw = pd.read_csv("/content/WEOOct2023all.xls", sep='\t', encoding='ISO-8859-1')
weo_selected_measurement = weo_raw.loc[weo_raw['WEO Subject Code'].str.contains("NGDP_RPCH", na=False)]
weo_selected_measurement_2018 = pd.DataFrame(weo_selected_measurement, columns=['Country', '2018'])

merged_train_data = pd.merge(hls_train, weo_selected_measurement_2018, on="Country")
merged_train_data = merged_train_data.rename(columns={"Value": yaxis, "2018": "Income Measurement"})
merged_train_data = pd.DataFrame(merged_train_data, columns=['Country', yaxis, 'Income Measurement'])
print(merged_train_data)

X= np.c_[merged_train_data["Income Measurement"]]
Y= np.c_[merged_train_data[yaxis]]
x = X.tolist()
y = Y.tolist()

model = sklearn.linear_model.LinearRegression()
model.fit(X,Y)

predicts = model.predict(X)
# plot data
out1 = widgets.Output()
with out1:
  plt.scatter(x, y)
  plt.xlabel('Income')
  plt.ylabel(yaxis)
  plt.title("Data Plot")
  plt.show()


# plot predictions
predict_x = [x for x in range(901)]
predict_x = [[x/100] for x in predict_x]
predict_y = model.predict(predict_x)

out2 = widgets.Output()
with out2:
  plt.scatter(predict_x, predict_y)
  plt.scatter(x, y)
  plt.xlabel('Income')
  plt.ylabel(yaxis)
  plt.title("Prediction Line")
  plt.show()

evs = explained_variance_score(Y, predicts)
print("Explained Variance Score: ", evs)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import explained_variance_score
import numpy as np
import pandas as pd
import ipywidgets as widgets
import matplotlib.pyplot as plt
import sklearn.linear_model

from google.colab import drive,files
drive.mount('/content/drive')

hls_all_raw = pd.read_csv("/content/HSL_16022024061254237.csv")
hls_slice = pd.DataFrame(hls_all_raw, columns =["Country","Indicator","Type of indicator","Time","Value"])

#yaxis = "Labour market insecurity"
#yaxis = "Feeling safe at night"
yaxis = "Social support"

hls_ls = hls_slice.loc[hls_all_raw["Indicator"] == yaxis]

hls_train = hls_ls.loc[hls_ls["Time"] == 2016]
hls_train = hls_train.loc[hls_ls["Type of indicator"] == 'Average']


weo_raw = pd.read_csv("/content/WEOOct2023all.xls", sep='\t', encoding='ISO-8859-1')
weo_selected_measurement = weo_raw.loc[weo_raw['WEO Subject Code'].str.contains("NGDP_RPCH", na=False)]
weo_selected_measurement_2018 = pd.DataFrame(weo_selected_measurement, columns=['Country', '2018'])

merged_train_data = pd.merge(hls_train, weo_selected_measurement_2018, on="Country")
merged_train_data = merged_train_data.rename(columns={"Value": yaxis, "2018": "Income Measurement"})
merged_train_data = pd.DataFrame(merged_train_data, columns=['Country', yaxis, 'Income Measurement'])
print(merged_train_data)

X= np.c_[merged_train_data["Income Measurement"]]
Y= np.c_[merged_train_data[yaxis]]
x = X.tolist()
y = Y.tolist()

model = sklearn.linear_model.LinearRegression()
model.fit(X,Y)

predicts = model.predict(X)
# plot data
out1 = widgets.Output()
with out1:
  plt.scatter(x, y)
  plt.xlabel('Income')
  plt.ylabel(yaxis)
  plt.title("Data Plot")
  plt.show()


# plot predictions
predict_x = [x for x in range(901)]
predict_x = [[x/100] for x in predict_x]
predict_y = model.predict(predict_x)

out2 = widgets.Output()
with out2:
  plt.scatter(predict_x, predict_y)
  plt.scatter(x, y)
  plt.xlabel('Income')
  plt.ylabel(yaxis)
  plt.title("Prediction Line")
  plt.show()

evs = explained_variance_score(Y, predicts)
print("Explained Variance Score: ", evs)
